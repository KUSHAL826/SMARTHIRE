# %% [markdown]
# # 02. Build FAISS Vector Index
# Load job corpus documents, chunk text, generate vector embeddings, and build the FAISS index.

# %%
from src.search.job_search import create_job_retriever
retriever = create_job_retriever()
print('FAISS index successfully built:', retriever)
