# %% [markdown]
# # 03. Prototype AI Career Mentor RAG Chain
# Test RAG retrieval and question answering with LangChain and ChatGoogleGenerativeAI.

# %%
from src.search.job_search import create_job_retriever
from src.mentor.rag_chain import create_rag_chain

retriever = create_job_retriever()
chain = create_rag_chain(retriever)
response = chain.invoke('What qualifications are needed for Machine Learning Engineer?')
print('RAG Mentor Response:', response)
